# %% [markdown]
# <a href="https://colab.research.google.com/github/hakimnagoya-debug/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Shah Reza Hakimi"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = "Pemrograman Dasar"
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Shah Reza Hakimi
# 19
# RPE
# 3
# Pemrograman Dasar
# False
